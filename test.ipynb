# %%
from create_venv import create_venv

# %%
create_venv(r"C:\Users\kurok\.pyenv\pyenv-win\versions\3.12.4\python.exe", r'C:\Users\kurok\Desktop\pythonFiles\PythonProjectManager\.venv')
# Out:
# Virtual environment created successfully at C:\Users\kurok\Desktop\pythonFiles\PythonProjectManager\.venv.
# True

# %%
from handle_data import interpreters_data

# %%
interpreters_data.interpreters = []
interpreters_data.interpreters.append(r"\.pyenv\pyenv-win\versions\3.12.4\python.exe")

# %%
interpreters_data.save()

# %%
import os
